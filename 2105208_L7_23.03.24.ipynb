# %%
import matplotlib 
import matplotlib.pyplot as plt

# %%
plt.plot(x,y,marker="o")

# %%
x=[1,2,3,4,5,6,7]
y=[10,20,30,40,50,60,70]
plt.plot(x,y)
plt.show()

# %%
a=np.array([1,2,3,4,5,6,7,8])
b=np.array([10,9,8,7,6,5,4,3])
plt.plot(x,y)
plt.show()

# %%
import numpy as np
a=np.arange(1,9)
b=np.arange(10,90,10)
plt.plot(a,b,color='red',marker='o',linestyle='dotted')
plt.show()

# %%
x = np.array([1,2,3,4,5,6,7,8])
y = np.array([3,4,5,6,7,8,9,10])

plt.plot(x,y, 'o')
plt.show()

# %%
x = np.array([1, 2, 6, 8])
y = np.array([3, 8, 1, 10])

plt.plot(x,y)
plt.show()

# %%
y = np.array([90,2.5,6,9,2])

plt.plot(y,color='g',marker='*')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20) #ms=marksize
plt.show()

# %%
import pandas as pd

# %%
pd.read_csv('employees.csv')
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df=pd.read_csv('employees.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.iloc[0:50]['Salary']
# Out:
# 0      97308
# 1      61933
# 2     130590
# 3     138705
# 4     101004
# 5     115163
# 6      65476
# 7      45906
# 8      95570
# 9     139852
# 10     63241
# 11    102508
# 12    112807
# 13    109831
# 14     41426
# 15     59414
# 16     90370
# 17    111737
# 18    132940
# 19     81014
# 20     64714
# 21    100612
# 22     90816
# 23    125792
# 24     97950
# 25     37076
# 26     37598
# 27    122367
# 28    124008
# 29     79529
# 30    118780
# 31     88657
# 32    122340
# 33    119082
# 34     95734
# 35     85182
# 36    142032
# 37     57427
# 38     36844
# 39    122173
# 40     99283
# 41     66582
# 42    121918
# 43     73524
# 44    145146
# 45     88010
# 46    114796
# 47     66820
# 48     93581
# 49    113590
# Name: Salary, dtype: int64

# %%
df['Salary'][:50]
# Out:
# 0      97308
# 1      61933
# 2     130590
# 3     138705
# 4     101004
# 5     115163
# 6      65476
# 7      45906
# 8      95570
# 9     139852
# 10     63241
# 11    102508
# 12    112807
# 13    109831
# 14     41426
# 15     59414
# 16     90370
# 17    111737
# 18    132940
# 19     81014
# 20     64714
# 21    100612
# 22     90816
# 23    125792
# 24     97950
# 25     37076
# 26     37598
# 27    122367
# 28    124008
# 29     79529
# 30    118780
# 31     88657
# 32    122340
# 33    119082
# 34     95734
# 35     85182
# 36    142032
# 37     57427
# 38     36844
# 39    122173
# 40     99283
# 41     66582
# 42    121918
# 43     73524
# 44    145146
# 45     88010
# 46    114796
# 47     66820
# 48     93581
# 49    113590
# Name: Salary, dtype: int64

# %%
salary=df.iloc[0:50]['Salary']
index=np.arange(0,50)
plt.plot(index,salary,color='g')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
salary=df.iloc[0:50]['Salary']
index=np.arange(0,50)
plt.bar(index,salary,color='g')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns.tolist()
# Out:
# ['First Name',
#  'Gender',
#  'Start Date',
#  'Last Login Time',
#  'Salary',
#  'Bonus %',
#  'Senior Management',
#  'Team']

# %%
sub=['ml','ai','cc','cd','nlp','spm']
std=[78,84,98,83,74,89]
plt.pie(std,labels=sub,autopct='%1.1f%%')
plt.show()

# %%
df['Team'].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
df['Team'].value_counts()
# Out:
# Team
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: count, dtype: int64

# %%
counts=df['Team'].value_counts()
valu=[106,102,101,98,95,94,92,91,90,88]
plt.pie(counts,autopct='%1.1f%%')
plt.show()

# %%
teams = df['Team']
team_counts = df['Team'].value_counts()
a = (0,0,0.3,0,0,0,0,0,0,0.5)
plt.pie(team_counts, labels=team_counts.index,explode=a,autopct='%1.1f%%')
plt.show()
